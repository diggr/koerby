# %%
import pandas as pd

# %%
wiki = pd.read_csv("source/wikidata_vg_companies.csv")

# %%
wiki.wkp = wiki.wkp.apply(lambda x: x.split("/")[-1])

# %%
wiki = wiki[wiki.name_en.notnull() | wiki.name_ja.notnull()]

# %%
wiki.to_csv("wiki_import", index=False)

# %%
wiki
# Out:
#             wkp                       name_en  \
# 0        Q73801             Microsoft Studios
# 1        Q94893                Rockstar North
# 2        Q94912                Rockstar Games
# 3        Q94933          Take-Two Interactive
# 4        Q94937                      2K Games
# 5       Q780528                         Atlus
# 6       Q782028                    Game Freak
# 7       Q795583                  Neowiz Games
# 8       Q488551                   Pentavision
# 9       Q494614          Sierra Entertainment
# 10     Q1137822                     Gala Inc.
# 11     Q1140960                    Sonic Team
# 12     Q1141245               Insomniac Games
# 13     Q1142226                  Nihon Falcom
# 14     Q1707830                 Sanzaru Games
# 15     Q1750959                Rockstar Leeds
# 16     Q1774120                     Kee Games
# 17     Q1781791            Namco Tales Studio
# 18     Q1782700      Infogrames Entertainment
# 19      Q115129               Silicon Knights
# 20      Q116371                       Q-Games
# 21      Q123018  Nintendo Software Technology
# 22      Q130744              Playground Games
# 23      Q133445                     2K Sports
# 24      Q133482               Visual Concepts
# 25      Q840550                   Alfa System
# 26      Q845047                          Koei
# 27     Q1143659          Nippon Ichi Software
# 28     Q1148541                   VisualArt's
# 29     Q1172213                     Data East
# ...         ...                           ...
# 2228  Q33575906               Critical Studio
# 2229  Q33576253                    Games Farm
# 2230  Q33704625                  E-Line Media
# 2231  Q33810505                    Wander MMO
# 2232  Q33811210                 Kew McParlane
# 2233  Q34365390                  Jasper Byrne
# 2234  Q39037814                  Matt Thorson
# 2235  Q39038111               Beam Team Games
# 2236  Q39047089                       Gamious
# 2237  Q40881750                  MovingBlocks
# 2238  Q41573694                   Pocket Gems
# 2239  Q41782945                           NaN
# 2240  Q42324284              Maschinen-Mensch
# 2241  Q42588527               Streetout Games
# 2242  Q42663892                    Animu Game
# 2243  Q42725768            Laundry Bear Games
# 2244  Q42901964                  Reborn Games
# 2245  Q44293084              Fruitbat Factory
# 2246  Q44296018                   Lucky Frame
# 2247  Q45057674                      InsGames
# 2248  Q45319364                     Turbulenz
# 2249  Q45321060                  Jujubee S.A.
# 2250  Q45321140            Evil Twin Artworks
# 2251  Q46617715              Private Division
# 2252  Q47086946             Callipygian Games
# 2253  Q47103585             Pocketwatch Games
# 2254  Q47110237       Killspace Entertainment
# 2255  Q47455664                    Witch Beam
# 2256  Q50896147                           NaN
# 2257     Q28225                       2K Play
#
#                                        name_ja
# 0                               マイクロソフトゲームスタジオ
# 1                               Rockstar North
# 2                               Rockstar Games
# 3                               テイクツー・インタラクティブ
# 4                                     2K Games
# 5                                         アトラス
# 6                                      ゲームフリーク
# 7                                 NeoWiz Japan
# 8                                  PENTAVISION
# 9                                シエラエンターテインメント
# 10                                         ガーラ
# 11                                     ソニックチーム
# 12                                インソムニアックゲームズ
# 13                                     日本ファルコム
# 14                                    サンザルゲームズ
# 15                              Rockstar Leeds
# 16                                      キーゲームズ
# 17                                ナムコ・テイルズスタジオ
# 18                                     インフォグラム
# 19                                     シリコンナイツ
# 20                                    キュー・ゲームス
# 21    Nintendo Software Technology Corporation
# 22                                  プレイグランドゲーム
# 23                                   2K Sports
# 24                             Visual Concepts
# 25                                   アルファ・システム
# 26                                        コーエー
# 27                                   日本一ソフトウェア
# 28                                    ビジュアルアーツ
# 29                                     データイースト
# ...                                        ...
# 2228                                       NaN
# 2229                                       NaN
# 2230                                       NaN
# 2231                                       NaN
# 2232                                       NaN
# 2233                                       NaN
# 2234                                       NaN
# 2235                                       NaN
# 2236                                       NaN
# 2237                                       NaN
# 2238                                       NaN
# 2239                                       NaN
# 2240                                       NaN
# 2241                                       NaN
# 2242                                       NaN
# 2243                                       NaN
# 2244                                       NaN
# 2245                                       NaN
# 2246                                       NaN
# 2247                                       NaN
# 2248                                       NaN
# 2249                                       NaN
# 2250                                       NaN
# 2251                                       NaN
# 2252                                       NaN
# 2253                                       NaN
# 2254                                       NaN
# 2255                                       NaN
# 2256                                       NaN
# 2257                                       NaN
#
# [2258 rows x 3 columns]

# %%
from kirby.kirby_dataset import KirbyEntry

# %%
entry = KirbyEntry()

# %%
len(entry)
# Out:
# 0

# %%
entry.id
# Out:
# '981cfead55cf454fb6b30abf9e4e72cf'

# %%
entry._sources
# Out:
# defaultdict(None, {})

# %%
entry["a"] = 99

# %%
entry
# Out:
# {'a': 99}

# %%
entry.id
# Out:
# '981cfead55cf454fb6b30abf9e4e72cf'

# %%
entry.serialize()
# Out:
# {'a': 99, 'kirby_id': '981cfead55cf454fb6b30abf9e4e72cf', 'sources': {}}

# %%
entry = KirbyEntry({"b": "yada"})
# Out:
# b yada

# %%
entry.serialize()
# Out:
# {'kirby_id': '83b7193f14f54f7b8fa150e9c4fba528', 'sources': {}}
